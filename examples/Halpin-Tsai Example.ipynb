# %% [markdown]
# # Plotting Example
#
# ## Halpin-Tsai Equations
#
# The Halpin-Tsai equation is given by:
# $$P_c = P_m \left (\frac{1 + \zeta \eta f}{1 - \eta f} \right)$$
# where
# $$\eta = \frac{P_f/P_m - 1}{P_f/P_m + \zeta}$$
# and $f$ is the fiber volume fraction, and $P$ is some propertry, with $c$ indicating composite properties, $f$ indicating fiber properties and $m$ indicating matrix properties
#
# For tensile modulus of aligned short-fiber composites, we have:
# $$\zeta = 2 l / d$$

# %% [markdown]
# ## Python Example
#
# Below we demonstrate a plot of tensile modulus vs. fiber aspect ratio using the Halpin-Tsai equations.
#
# First we load the relevant python libraries for plotting

# %%
from ipywidgets import interact
import numpy as np
from bokeh.plotting import figure, output_notebook, show
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="c82baf8d-924c-499e-ada0-fe2b5289da90">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# Next, we set up an array for fiber aspect ratio

# %%
ld = np.linspace(1,200) #fiber aspect ratio array

# %% [markdown]
# Now we calculate zeta and eta for each fiber aspect ratio. To calculate $\eta$ we need to know the ratio of fiber to matrix stiffness, we will assume $E_f/E_m = 100$ in this example.

# %%
zeta = 2*ld
eta = (100-1)/(100+zeta)

# %% [markdown]
# Now we can normalize the Halpin-Tsai equation by dividing both sides by $E_m$, we can calculate this and plot it vs. fiber aspect ratio. We will assume a fiber volume fraction of 20%.

# %%
f = 0.20 # 20% volume fraction
Ec_Em_20 = (1+zeta*eta*f)/(1-eta*f)

# %% [markdown]
# Finally we can create the plot in Python.

# %%
p = figure(title="Halpin-Tsai Example", plot_height=300, plot_width=600)
r = p.line(ld, Ec_Em_20, color="#2222aa", line_width=3)
p.xaxis.axis_label='Aspect Ratio (l/d)'
p.yaxis.axis_label='Reinforcement (Ec/Em)'

# %%
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ba13c62a-8c10-4cc7-9734-722738709ecd"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("ba13c62a-8c10-4cc7-9734-722738709ecd").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ba13c62a-8c10-4cc7-9734-722738709ecd");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ba13c62a-8c10-4cc7-9734-722738709ecd' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"1b768f02-af8d-4838-89bb-fbfd94d31c47":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"1436b565-43d5-4371-afb6-d49123191401","type":"PanTool"},{"id":"e39100c6-89af-4ee7-9595-2e3bd721e223","type":"WheelZoomTool"},{"id":"330d2ac0-6ae8-4715-8cfd-b43bad36ac87","type":"BoxZoomTool"},{"id":"524eb261-2f28-494c-9c1c-a230b846d266","type":"SaveTool"},{"id":"fd182efa-ab8e-4444-8c74-cbdac509d8ce","type":"ResetTool"},{"id":"c3610d9a-90c7-496c-9d4a-8919b3cf7632","type":"HelpTool"}]},"id":"96829053-e1e0-4e58-bb31-8d61d7e68a72","type":"Toolbar"},{"attributes":{"callback":null},"id":"2f281625-8193-4923-a0cb-14376d0ec71e","type":"DataRange1d"},{"attributes":{"plot":{"id":"6a3f0d0f-8122-4579-8146-4e63c3cc7e60","subtype":"Figure","type":"Plot"}},"id":"fd182efa-ab8e-4444-8c74-cbdac509d8ce","type":"ResetTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":
type":"ColumnDataSource"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"a174cbfa-3acd-4e67-acba-9ad23cb6fe17","type":"Line"},{"attributes":{},"id":"79e0a98f-dfce-4603- ...

# %% [markdown]
# Now we can also look at the effect of various volume fractions

# %%
f = 0.10 # 10% volume fraction
Ec_Em_10 = (1+zeta*eta*f)/(1-eta*f)

f = 0.30 # 10% volume fraction
Ec_Em_30 = (1+zeta*eta*f)/(1-eta*f)

# %%
p2 = figure(title="Halpin-Tsai Example 2", plot_height=300, plot_width=600)
r1 = p2.line(ld, Ec_Em_10, color = 'navy', line_width=3)
r2 = p2.line(ld, Ec_Em_20, color = 'firebrick', line_width=3)
r3 = p2.line(ld, Ec_Em_30, color = 'olive', line_width=3)
p2.xaxis.axis_label='Aspect Ratio (l/d)'
p2.yaxis.axis_label='Reinforcement (Ec/Em)'
show(p2)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="92560eff-fac1-434d-9002-72b09eacd43f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("92560eff-fac1-434d-9002-72b09eacd43f").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("92560eff-fac1-434d-9002-72b09eacd43f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '92560eff-fac1-434d-9002-72b09eacd43f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6eee2c27-8bdd-4eb9-9a23-87a8e945a869":{"roots":{"references":[{"attributes":{"data_source":{"id":"2dc35c36-0736-4a06-9d00-a181c721f94f","type":"ColumnDataSource"},"glyph":{"id":"e9424aa9-bbcd-4c73-9787-3dc3c03a8ea2","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"e5f60283-5413-4b6e-911c-d4c3923bb609","type":"Line"},"selection_glyph":null},"id":"da1d4370-567a-4276-a0a9-6f9011f08c7d","type":"GlyphRenderer"},{"attributes":{"line_color":{"value":"olive"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"d43c8796-cdb7-4202-bd6a-0a3c3672eb54","type":"Line"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[50]},"y":{"__ndarray__":"...","dtype":"float64","shape":[50]}}},"id":"8d97168a-6e4d-4dc6-906c-12fa29954b01","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[50]},"y":{"__ndarray__":"...","dtype":"float64","shape":[50]}}},"id":"2dc35c36-0736-4a06-9d00-a181c721f94f","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"2b6d6087-fdf6-4ae8-8a5f-57e600e91cfb","type":"DataRange1d"},{"attributes":{"line_color":{"value":"navy"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"4428703a-1e1b-427b-9ed5-192bd508bdee","type":"Line"},{"attributes":{"plot":{"id":"92c30529-c410-4837-ac40-f0f4c354cc52","subtype":"Figure","type":"Plot"}},"id":"38c35843-071f-4117-9c8a-b4270099c298","type":"ResetTool"},{"attributes":{"axis_label":"Reinforcement (Ec/Em)","formatter":{"id":"3c328d47-0a22-4eac-b0ab-da64b1d15b20","type":"BasicTickFormatter"},"plot":{"id":"92c30529-c410-4837-ac40-f0f4c354cc52","subtype":"Figure","type":"Plot"},"ticker":{"id":"9adf0abd-113b-4068-a291-dd25f6786302","type":"BasicTicker"}},"id":"e8376122-3985-469f-a605-4dd1e354c90c","type":"LinearAxis"},{"attributes":{"overlay":{"id":"a61552fa-b04d-4b20-96b0-dcc7a3569996","type":"BoxAnnotation"},"plot":{"id":"92c30529-c410-4837-ac40-f0f4c354cc52","subtype":"Figure","type":"Plot"}},"id":"35061675-a8bf-4905-ac53-8fb31359e1c7","type":"BoxZoomTool"},{"attributes":{"line_color":{"value":"firebrick"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"e9424aa9-bbcd-4c73-9787-3dc3c03a8ea2","type":"Line"},{"attributes":{"plot":{"id":"92c30529-c410-4837-ac40-f0f4c354cc52","subtype":"Figure","type":"Plot"}},"id":"5c882f2a-3b71-49e2-92a0-432a0fa91581","type":"PanTool"},{"attributes":{"data_source":{"id":"8d97168a-6e4d-4dc6-906c-12fa29954b01","type":"ColumnDataSource"},"glyph":{"id":"d43c8796-cdb7-4202-bd6a-0a3c3672eb54","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"338aa6fc-b9f8-453d-8998-4e4df9bf1520","type":"Line"},"selection_glyph":null},"id":"7b5bdcb0-ee45-4285-98d5-f112879e9cdb","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"92c30529-c410-4837-ac40-f0f4c354cc52","subtype":"Figure","type":"Plot"},"ticker":{"id":"0ba8842a-18ef-40be-a57e-d92921d47d13","type":"BasicTicker"}},"id":"2d15ecaf-7fdf-4160-9900-42472aa8ea31","type":"Grid"},{"attributes":{},"id":"9adf0abd-113b-4068-a291-dd25f6786302","type":"BasicTicker"},{"attributes":{"plot":null,"text":"Halpin-Tsai Example 2"},"id":"20507e87-a1e2-4c57-9bdf-f2be48fd9b38","type":"Title"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"a61552fa-b04d-4b20-96b0-dcc7a3569996","type":"BoxAnnotation"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"d486c1d4-d723-4f59-bbff-eb9cbbe38bab","type":"Line"},{"attributes":{"below":[{"id":"05b9d772-f65b-43e6-bcc7-bf35c572685e","type":"LinearAxis"}],"left":[{"id":"e8376122-39 ...

# %% [markdown]
# It looks like this data might be better represented on a log-scale for the x-axis, let's see:

# %%
ld = np.logspace(0,2.2) #fiber aspect ratio array
zeta = 2*ld
eta = (100-1)/(100+zeta)
f = 0.10 # 10% volume fraction
Ec_Em_10 = (1+zeta*eta*f)/(1-eta*f)
f = 0.20 # 20% volume fraction
Ec_Em_20 = (1+zeta*eta*f)/(1-eta*f)
f = 0.30 # 10% volume fraction
Ec_Em_30 = (1+zeta*eta*f)/(1-eta*f)
p3 = figure(title="Halpin-Tsai Example 3", plot_height=300, plot_width=600,x_axis_type='log')
r1 = p3.line(ld, Ec_Em_10, color = 'navy', line_width=3, legend = '10%')
r2 = p3.line(ld, Ec_Em_20, color = 'firebrick', line_width=3, legend = '20%')
r3 = p3.line(ld, Ec_Em_30, color = 'olive', line_width=3, legend = '30%')
p3.xaxis.axis_label='Aspect Ratio (l/d)'
p3.yaxis.axis_label='Reinforcement (Ec/Em)'
p3.legend.location = 'top_left'
show(p3)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="6d03f893-f9a5-4f38-aa98-19d612a22a05"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("6d03f893-f9a5-4f38-aa98-19d612a22a05").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6d03f893-f9a5-4f38-aa98-19d612a22a05");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6d03f893-f9a5-4f38-aa98-19d612a22a05' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"256ec66a-9e7a-484b-b2ec-b5cc19f607e2":{"roots":{"references":[{"attributes":{"data_source":{"id":"bc710075-7bc6-4919-8156-aa4b0693c45d","type":"ColumnDataSource"},"glyph":{"id":"179a3c1d-4e95-42a2-bb72-7099fdbeaa9a","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"461f9bda-f8f5-4697-9eb5-789ccdee6ad8","type":"Line"},"selection_glyph":null},"id":"7edeff51-74fe-4427-86c3-eeb7abc33948","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"2d72850a-8c4c-407f-a63c-364fe0759932","type":"Line"},{"attributes":{"line_color":{"value":"firebrick"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"cca7e279-77e8-40bc-9422-ad881c9b5260","type":"Line"},{"attributes":{"data_source":{"id":"6bbe74bd-4076-4e17-b1dc-3c33cfc89d52","type":"ColumnDataSource"},"glyph":{"id":"80db08de-3825-4131-a237-5196d396d326","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"2d72850a-8c4c-407f-a63c-364fe0759932","type":"Line"},"selection_glyph":null},"id":"916179d1-ea40-431b-87ad-6ecbe0847735","type":"GlyphRenderer"},{"attributes":{"num_minor_ticks":10},"id":"b99db4f8-ba66-43db-9bbe-5a838c597975","type":"LogTicker"},{"attributes":{"plot":{"id":"3ae39193-4a75-4ac0-a67c-a2e39f20425f","subtype":"Figure","type":"Plot"}},"id":"30e34de6-bd27-47f7-9132-1aaafc55e059","type":"WheelZoomTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"461f9bda-f8f5-4697-9eb5-789ccdee6ad8","type":"Line"},{"attributes":{"plot":{"id":"3ae39193-4a75-4ac0-a67c-a2e39f20425f","subtype":"Figure","type":"Plot"}},"id":"28615cab-a282-4a60-89d4-edf3eb94c209","type":"ResetTool"},{"attributes":{"data_source":{"id":"8916c220-c352-47a0-8433-034c3cf96a60","type":"ColumnDataSource"},"glyph":{"id":"cca7e279-77e8-40bc-9422-ad881c9b5260","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"4c8c5e4b-3536-48b1-bc80-1a38b55393cf","type":"Line"},"selection_glyph":null},"id":"5ebe866f-48e3-4fb2-8508-8f3d0f657abd","type":"GlyphRenderer"},{"attributes":{"line_color":{"value":"olive"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"80db08de-3825-4131-a237-5196d396d326","type":"Line"},{"attributes":{"ticker":null},"id":"12484b62-4632-4405-a876-0a950d9ab954","type":"LogTickFormatter"},{"attributes":{"axis_label":"Aspect Ratio (l/d)","formatter":{"id":"12484b62-4632-4405-a876-0a950d9ab954","type":"LogTickFormatter"},"plot":{"id":"3ae39193-4a75-4ac0-a67c-a2e39f20425f","subtype":"Figure","type":"Plot"},"ticker":{"id":"b99db4f8-ba66-43db-9bbe-5a838c597975","type":"LogTicker"}},"id":"bd5b7f3a-6087-4ee2-ac7c-1016c3943cb6","type":"LogAxis"},{"attributes":{"line_color":{"value":"navy"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"179a3c1d-4e95-42a2-bb72-7099fdbeaa9a","type":"Line"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"aa5844df-b8d5-42b7-96be-0c1b7ec492bc","type":"PanTool"},{"id":"30e34de6-bd27-47f7-9132-1aaafc55e059","type":"WheelZoomTool"},{"id":"e4881372-a5d6-4adf-9edc-a5db7fb3f5b7","type":"BoxZoomTool"},{"id":"48ac7ac3-4809-4210-adef-544f45ac895f","type":"SaveTool"},{"id":"28615cab-a282-4a60-89d4-edf3eb94c209","type":"ResetTool"},{"id":"4bb95c51-844a-45c5-888f-188043e0c699","type":"HelpTool"}]},"id":"934836f9-8624-491e-84c4-d59d2ba5114a","type":"Toolbar"},{"attributes":{"plot":{"id":"3ae39193-4a75-4ac0-a67c-a2e39f20425f","subtype":"Figure","type":"Plot"}},"id":"48ac7ac3-4809-4210-adef-544f45ac895f","type":"SaveTool"},{"attributes":{"dimension":1,"plot":{"id":"3ae39193-4a75-4ac0-a67c-a2e39f20425f","subtype":"Figure","type":"Plot"},"ticker":{"id":"266479cb-a539-4be8-810b-cc0559fcf55c","type":"BasicTicker"}},"id":"fd3cf9cc-b8cd-4348-83da-8f3573be31fd","type":"Grid"},{"attributes":{"axis_label":"Reinforcement (Ec/Em)","formatter":{"id":"ace7 ...

# %% [markdown]
# ## Experimental Data
#
# It is general practice in scientific plots to use connected lines for models (which imply some kind of smooth connection between points) and un-connected symbols for things with no implied connection, such as unique finite element models, tensile tests, etc.
#
# Here we will generate a few fake finite element tests to plot in comparison with our real data.

# %%
ld_fe = np.logspace(0,2.2,6)
zeta = 2*ld_fe
eta = (100-1)/(100+zeta)
f = 0.10 # 10% volume fraction
Ec_Em_10_fe = (1+zeta*eta*f)/(1-eta*f)*np.random.normal(1,0.1,6)
f = 0.20 # 20% volume fraction
Ec_Em_20_fe = (1+zeta*eta*f)/(1-eta*f)*np.random.normal(1,0.1,6)
f = 0.30 # 10% volume fraction
Ec_Em_30_fe = (1+zeta*eta*f)/(1-eta*f)*np.random.normal(1,0.1,6)

# %%
p4 = figure(title="Halpin-Tsai Example 4", plot_height=300, plot_width=600,x_axis_type='log')
r1 = p4.line(ld, Ec_Em_10, color = 'navy', line_width=3, legend = '10% - HT')
r2 = p4.line(ld, Ec_Em_20, color = 'firebrick', line_width=3, legend = '20% - HT')
r3 = p4.line(ld, Ec_Em_30, color = 'olive', line_width=3, legend = '30% - HT')
r4 = p4.circle(ld_fe, Ec_Em_10_fe, size=10,color = 'navy', fill_color='white',line_width=1.5, legend = '10% - FE')
r5 = p4.circle(ld_fe, Ec_Em_20_fe, size=10, color = 'firebrick', fill_color='white',line_width=1.5, legend = '20% - FE')
r6 = p4.circle(ld_fe, Ec_Em_30_fe, size=10,color = 'olive', fill_color='white',line_width=1.5, legend = '30% - FE')
p4.xaxis.axis_label='Aspect Ratio (l/d)'
p4.yaxis.axis_label='Reinforcement (Ec/Em)'
p4.legend.location = 'top_left'
show(p4)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8d0a284b-ca46-4f75-989d-9fc1d902cfce"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("8d0a284b-ca46-4f75-989d-9fc1d902cfce").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8d0a284b-ca46-4f75-989d-9fc1d902cfce");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8d0a284b-ca46-4f75-989d-9fc1d902cfce' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"94c6a839-fa28-413b-b0c0-841d54633957":{"roots":{"references":[{"attributes":{"below":[{"id":"f3b71a13-2e74-4acc-a32b-89a1e025163c","type":"LogAxis"}],"left":[{"id":"7252bac7-f9fb-4272-a4a6-3a86ec835b80","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":"f3b71a13-2e74-4acc-a32b-89a1e025163c","type":"LogAxis"},{"id":"c6cbaa5e-8902-48cf-8e23-2687c85120a3","type":"Grid"},{"id":"7252bac7-f9fb-4272-a4a6-3a86ec835b80","type":"LinearAxis"},{"id":"ab1f1107-fa17-494b-aff6-bb02abe71164","type":"Grid"},{"id":"871ff5db-efa0-4005-bfb0-bfcd0ca62983","type":"BoxAnnotation"},{"id":"7a08a6cd-918e-4cb3-9f2d-501f6998235c","type":"Legend"},{"id":"8f8a750b-9282-4e16-9ac7-28a57e40d941","type":"GlyphRenderer"},{"id":"fe3eb1fe-a85c-4ee3-96ac-18a80f0b8902","type":"GlyphRenderer"},{"id":"90c8bd1f-da9e-4f5b-a853-7684971f82c9","type":"GlyphRenderer"},{"id":"c54b7e63-a819-4af0-a568-270f4cf7fc88","type":"GlyphRenderer"},{"id":"56d0c870-